# %%
students = {'Alice': 20, 'Bob': 22, 'Charlie': 21}
print(students)
# Out:
# {'Alice': 20, 'Bob': 22, 'Charlie': 21}

# %%
data1 = {'a': 1, 'b': 2, 'c': 3}
data1['data1'] = 4
print(data1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'data1': 4}

# %%
stud = {'name': 'John', 'age': 25, 'city': 'New York'}
print(stud.keys())
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
sub = {'python': 3, 'java': 2, 'c++': 1}
print(sub.values())
# Out:
# dict_values([3, 2, 1])

# %%
studata = {'name': 'Alice', 'age': 30, 'city': 'London'}
print('age' in studata)
# Out:
# True

# %%
alph = {'a': 1, 'b': 2, 'temp': 3, 'c': 4}
alph.pop('temp')
print(alph)
# Out:
# {'a': 1, 'b': 2, 'c': 4}

# %%
subject = {'math': 85, 'science': 92, 'english': 78}
print(sum(subject.values()))
# Out:
# 255

# %%
squares = {i: i**2 for i in range(1, 6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
squares = {i: i**2 for i in range(1, 6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
s = "hello"
freq = {}
for char in s:
    freq[char] = freq.get(char, 0) + 1
print(freq)
# Out:
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
dic1 = {'a': 1, 'b': 2}
dic2 = {'c': 3, 'd': 4}
print({**dic1, **dic2})
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
data = {'person': {'name': 'Alice', 'age': 25}}
print(data)
# Out:
# {'person': {'name': 'Alice', 'age': 25}}

# %%
print(data['person']['name'])
# Out:
# Alice

# %%
fruit = {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}
print(fruit)
# Out:
# {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}

# %%
color = {'coordinates': (10, 20), 'rgb': (255, 0, 0)}
print(color)
# Out:
# {'coordinates': (10, 20), 'rgb': (255, 0, 0)}

# %%
print(color['coordinates'][0])
# Out:
# 10

# %%
alpha = {'vowels': {'a', 'e', 'i'}, 'consonants': {'b', 'c', 'd'}}
print(alpha)
# Out:
# {'vowels': {'a', 'e', 'i'}, 'consonants': {'b', 'd', 'c'}}

# %%
alpha['vowels'].add('o')
print(alpha)
# Out:
# {'vowels': {'a', 'e', 'o', 'i'}, 'consonants': {'b', 'd', 'c'}}

# %%
emp = {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}
print(emp)
# Out:
# {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}

# %%
print(emp['company']['department']['employee']['name'])
# Out:
# John

# %%
data = {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}
print(data)
# Out:
# {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}

# %%
for k, v in d.items():
    print(k, type(v))
# Out:
# math <class 'int'>
# science <class 'int'>
# english <class 'int'>

# %%
 a = {'len': len, 'str': str, 'int': int}
print(a)
# Out:
# {'len': <built-in function len>, 'str': <class 'str'>, 'int': <class 'int'>}

# %%
for k, func in a.items():
    print(k, func("123"))
# Out:
# len 3
# str 123
# int 123

# %%
dim = {'double': lambda x: x*2, 'square': lambda x: x**2}
print(dim)
# Out:
# {'double': <function <lambda> at 0x7ea9827ae020>, 'square': <function <lambda> at 0x7ea9827ae2a0>}

# %%
for m, func in dim.items():
    print(m, func(5))
# Out:
# double 10
# square 25

# %%
d = {'list': list, 'dict': dict, 'set': set}
print(d)
# Out:
# {'list': <class 'list'>, 'dict': <class 'dict'>, 'set': <class 'set'>}

# %%
for k, cls in d.items():
    print(k, cls())
# Out:
# list []
# dict {}
# set set()

# %%
d = {'a': None, 'b': None, 'c': None}
print(d)
# Out:
# {'a': None, 'b': None, 'c': None}

# %%
d = {k: 0 if v is None else v for k, v in d.items()}
print(d)
# Out:
# {'a': 0, 'b': 0, 'c': 0}

# %%
admin = {'is_active': True, 'is_admin': False}
print(admin)
# Out:
# {'is_active': True, 'is_admin': False}

# %%
print(sum(admin.values()))
# Out:
# 1

# %%
exp = {'z1': 3+4j, 'z2': 1+2j}
print(exp)
# Out:
# {'z1': (3+4j), 'z2': (1+2j)}

# %%
for k, v in d.items():
    print(k, abs(v))
# Out:
# a 0
# b 0
# c 0

# %%
Alp = {'a': {'b': {'c': {'d': 100}}}}
print(Alp)
# Out:
# {'a': {'b': {'c': {'d': 100}}}}

# %%
print(Alp['a']['b']['c']['d'])
# Out:
# 100

# %%
rn = {'r1': range(3), 'r2': range(5)}
print(rn)
# Out:
# {'r1': range(0, 3), 'r2': range(0, 5)}

# %%
rn = {k: list(v) for k, v in rn.items()}
print(rn)
# Out:
# {'r1': [0, 1, 2], 'r2': [0, 1, 2, 3, 4]}

# %%
vec = {k: [v] for k, v in d.items()}
print(vec)
# Out:
# {'points': [((1, 2), (3, 4))], 'rgb': [((255, 0, 0), (0, 255, 0))]}

# %%
a1 = {k: list(v) for k, v in d.items()}
print(a1)
# Out:
# {'points': [(1, 2), (3, 4)], 'rgb': [(255, 0, 0), (0, 255, 0)]}

# %%
it = {'it1': iter([1, 2, 3]), 'it2': iter([4, 5, 6])}
print(it)
# Out:
# {'it1': <list_iterator object at 0x7ea982982260>, 'it2': <list_iterator object at 0x7ea982980250>}

# %%
for k, it in d.items():
    print(k, list(it))
# Out:
# a [0]
# b [0]
# c [0]

# %%
dimension = {'matrix': [[1, 2], [3, 4]], 'vector': [5, 6, 7]}
print(dimension)
# Out:
# {'matrix': [[1, 2], [3, 4]], 'vector': [5, 6, 7]}

# %%
dms = {'matrix': [[1, 2], [3, 4]], 'vector': [5, 6, 7]}
print(dms)
# Out:
# {'matrix': [[1, 2], [3, 4]], 'vector': [5, 6, 7]}

# %%
d = {'config': {'db': {'host': 'localhost', 'port': 5432}}}
print(d)
# Out:
# {'config': {'db': {'host': 'localhost', 'port': 5432}}}

# %%
print(d['config']['db']['port'])
# Out:
# 5432

# %%
c = {'points': ((1, 2), (3, 4)), 'rgb': ((255, 0, 0), (0, 255, 0))}
print(c)
# Out:
# {'points': ((1, 2), (3, 4)), 'rgb': ((255, 0, 0), (0, 255, 0))}

# %%
print(c['points'][0])
# Out:
# (1, 2)

# %%
grp = {'groups': [{1, 2, 3}, {4, 5, 6}], 'categories': [{'a', 'b'}, {'c', 'd'}]}
print(grp)
# Out:
# {'groups': [{1, 2, 3}, {4, 5, 6}], 'categories': [{'a', 'b'}, {'c', 'd'}]}

# %%
union_set = set()
for sets in d.values():
    for s in sets:
        union_set.update(s)
print(union_set)
# Out:
# {0, 1, 2, 3, 4, 255}
