# %%
x = None
print(x)
# Out:
# None

# %%
print(None == None)
# Out:
# True

# %%
print(None is None)
# Out:
# True

# %%
print(f'0 is None: {0 is None}')

# %%
print(False is None)
# Out:
# False

# %%
print([] is None)
# Out:
# False

# %%
print({} is None)
# Out:
# False

# %%
print(set() is None)
# Out:
# False
